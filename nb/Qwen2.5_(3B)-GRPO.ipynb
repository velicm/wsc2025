# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [blog post](https://unsloth.ai/blog/r1-reasoning) for guidance on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
# Skip restarting message in Colab
import sys; modules = list(sys.modules.keys())
for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None

# !pip install unsloth vllm
# !pip install --upgrade pillow

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Use `PatchFastRL` before all functions to patch GRPO and other RL algorithms!

# %%
# !pip install wandb
import os
from google.colab import userdata
os.environ["WANDB_API_KEY"] = userdata.get('wandb')
os.environ["WANDB_PROJECT"] = "GRPO-Qwen-2.5-3B-Instruct"
# !wandb login
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.6)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.10.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.21.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
from unsloth import FastLanguageModel, PatchFastRL
PatchFastRL("GRPO", FastLanguageModel)
# Out:
# Unsloth: Patching Xformers to fix some performance issues.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 02-15 16:48:21 __init__.py:190] Automatically detected platform cuda.

# %% [markdown]
# Load up `Qwen 2.5 3B Instruct`, and set parameters

# %%
from unsloth import is_bfloat16_supported
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 64 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen2.5-3B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.5, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# ==((====))==  Unsloth 2025.2.12: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit with actual GPU utilization = 49.48%
# Unsloth: Your GPU has CUDA compute capability 8.0 with VRAM = 39.56 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 1024. Num Sequences = 288.
# Unsloth: vLLM's KV Cache can use up to 17.15 GB. Also swap space = 6 GB.
# INFO 02-15 16:49:06 config.py:542] This model supports multiple tasks: {'score', 'embed', 'classify', 'generate', 'reward'}. Defaulting to 'generate'.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'bfloat16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.2.mlp', 'model.layers.3.mlp', 'model.layers.30.mlp'], 'llm_int8_threshold': 6.0}
# INFO 02-15 16:49:06 llm_engine.py:234] Initializing a V0 LLM engine (v0.7.2) with config: model='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=1024, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":288}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# INFO 02-15 16:49:13 cuda.py:230] Using Flash Attention backend.
# INFO 02-15 16:49:14 model_runner.py:1110] Starting to load model unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit...
# INFO 02-15 16:49:14 loader.py:1102] Loading weights with BitsAndBytes quantization.  May take a while ...
# INFO 02-15 16:49:15 weight_utils.py:252] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 02-15 16:49:23 model_runner.py:1115] Loading model weights took 2.2160 GB
# INFO 02-15 16:49:23 punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 02-15 16:49:31 worker.py:267] Memory profiling takes 7.56 seconds
# INFO 02-15 16:49:31 worker.py:267] the current vLLM instance can use total_gpu_memory (39.56GiB) x gpu_memory_utilization (0.49) = 19.57GiB
# INFO 02-15 16:49:31 worker.py:267] model weights take 2.22GiB; non_torch_memory takes 0.09GiB; PyTorch activation peak memory takes 1.57GiB; the rest of the memory reserved for KV Cache is 15.70GiB.
# INFO 02-15 16:49:32 executor_base.py:110] # CUDA blocks: 28573, # CPU blocks: 10922
# INFO 02-15 16:49:32 executor_base.py:115] Maximum concurrency for 1024 tokens per request: 446.45x
# INFO 02-15 16:49:36 model_runner.py:1434] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 39/39 [00:54<00:00,  1.41s/it]
# INFO 02-15 16:50:31 model_runner.py:1562] Graph capturing finished in 55 secs, took 0.92 GiB
# INFO 02-15 16:50:31 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 68.23 seconds
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Unsloth 2025.2.12 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
# Out:
# wandb: Currently logged in as: velic (velic-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset('openai/gsm8k', 'main')[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# README.md:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 8, # Decrease if out of memory
    max_prompt_length = 256,
    max_completion_length = 256,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We know expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 8

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 7,473 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 8 | Gradient Accumulation steps = 1
# \        /    Total batch size = 8 | Total steps = 250
#  "-____-"     Number of trainable parameters = 119,734,272
# -------------------- Question:
# A concert ticket costs $40. Mr. Benson bought 12 tickets and received a 5% discount for every ticket bought that exceeds 10. How much did Mr. Benson pay in all?
# Answer:
# 476
# Response:
# <reasoning>
# Mr. Benson bought 12 concert tickets. The first 10 tickets were bought at full price, and the additional 2 tickets received a 5% discount.
#
# The cost of each ticket at full price is $40. The cost of each discounted ticket is $40 * (1 - 0.05) = $40 * 0.95 = $38.
#
# So, Mr. Benson paid $40 * 10 = $400 for the first 10 tickets.
# And for the additional 2 tickets, he paid $38 * 2 = $76.
#
# Therefore, the total amount Mr. Benson paid is $400 + $76 = $476.
# </reasoning>
# <answer>
# Mr. Benson paid a total of $476 for all the concert tickets.
# </answer>
# Extracted:
# Mr. Benson paid a total of $476 for all the concert tickets.
#     <div>
#
#       <progress value='28' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 28/250 03:30 < 29:55, 0.12 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / xmlcount_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / int_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-0.137125</td>
#       <td>0.284612</td>
#       <td>235.750000</td>
#       <td>0.000000</td>
#       <td>-0.137125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>-0.159375</td>
#       <td>0.395573</td>
#       <td>256.000000</td>
#       <td>0.000000</td>
#       <td>-0.159375</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.285750</td>
#       <td>0.345081</td>
#       <td>252.125000</td>
#       <td>0.000285</td>
#       <td>-0.285750</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-0.107625</td>
#       <td>0.282965</td>
#       <td>232.625000</td>
#       <td>0.000760</td>
#       <td>-0.107625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-0.116125</td>
#       <td>0.124394</td>
#       <td>212.625000</td>
#       <td>0.000395</td>
#       <td>-0.116125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>256.000000</td>
#       <td>0.000232</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>256.000000</td>
#       <td>0.000373</td>
#       <td>0.125000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-0.135250</td>
#       <td>0.394532</td>
#       <td>234.375000</td>
#       <td>0.000524</td>
#       <td>-0.135250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.109625</td>
#       <td>0.949712</td>
#       <td>239.500000</td>
#       <td>0.000737</td>
#       <td>-0.202875</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.061125</td>
#       <td>0.180666</td>
#       <td>256.000000</td>
#       <td>0.000408</td>
#       <td>0.061125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.200875</td>
#       <td>0.888293</td>
#       <td>236.000000</td>
#       <td>0.000475</td>
#       <td>-0.111625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-0.392000</td>
#       <td>0.282391</td>
#       <td>242.375000</td>
#       <td>0.000544</td>
#       <td>-0.392000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-0.081125</td>
#       <td>0.207305</td>
#       <td>221.250000</td>
#       <td>0.000608</td>
#       <td>-0.081125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-0.004125</td>
#       <td>0.256838</td>
#       <td>250.750000</td>
#       <td>0.000580</td>
#       <td>-0.004125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-0.051250</td>
#       <td>0.326405</td>
#       <td>256.000000</td>
#       <td>0.000499</td>
#       <td>-0.051250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.228000</td>
#       <td>0.908790</td>
#       <td>217.625000</td>
#       <td>0.000594</td>
#       <td>-0.147000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>-0.315500</td>
#       <td>0.300206</td>
#       <td>249.750000</td>
#       <td>0.000395</td>
#       <td>-0.315500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-0.056250</td>
#       <td>0.253830</td>
#       <td>250.875000</td>
#       <td>0.000359</td>
#       <td>-0.056250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>-0.128750</td>
#       <td>0.262664</td>
#       <td>233.000000</td>
#       <td>0.000441</td>
#       <td>-0.128750</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.033250</td>
#       <td>0.259508</td>
#       <td>256.000000</td>
#       <td>0.000491</td>
#       <td>0.033250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.261875</td>
#       <td>0.819747</td>
#       <td>243.625000</td>
#       <td>0.000612</td>
#       <td>-0.050625</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.129250</td>
#       <td>0.193489</td>
#       <td>190.875000</td>
#       <td>0.000391</td>
#       <td>-0.129250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000100</td>
#       <td>0.060250</td>
#       <td>0.972040</td>
#       <td>174.750000</td>
#       <td>0.001677</td>
#       <td>-0.252250</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.058875</td>
#       <td>0.244179</td>
#       <td>238.000000</td>
#       <td>0.000583</td>
#       <td>-0.058875</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000100</td>
#       <td>-0.254500</td>
#       <td>0.146034</td>
#       <td>186.000000</td>
#       <td>0.001466</td>
#       <td>-0.254500</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>-0.142000</td>
#       <td>0.207490</td>
#       <td>230.500000</td>
#       <td>0.000703</td>
#       <td>-0.142000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# -------------------- Question:
# Jane is trying to decide whether to buy a house or a trailer. A house costs $480,000 and a trailer costs $120,000. Each loan will be paid in monthly installments over 20 years. How much more is the monthly payment on the house compared to the trailer?
# Answer:
# 1500
# Response:
# <reasoning>
# Let's first calculate the monthly payment amount for both the house and the trailer.
#
# First, convert the loan terms into monthly terms:
# - The house cost is $480,000 and will be paid over 20 years, which is 240 months (20 years * 12 months/year).
# - The trailer cost is $120,000 and will also be paid over 20 years, which is also 240 months.
#
# For the house, the monthly payment \( M_h \) can be calculated using the loan formula:
# \[ M_h = \frac{P \times r \times (1 + r)^n}{(1 + r)^n - 1} \]
# where \( P \) is the loan amount, \( r \) is the monthly interest rate, and \( n \) is the number of months.
# Assuming an interest rate \( r \) of 0.008333 (1% per month, which is equivalent to 12% per year over 20 years), the calculation would be:
# \[ M_h = \frac{480,000 \times 0.008
# Extracted:
# <reasoning>
# Let's first calculate the monthly payment amount for both the house and the trailer.
#
# First, convert the loan terms into monthly terms:
# - The house cost is $480,000 and will be paid over 20 years, which is 240 months (20 years * 12 months/year).
# - The trailer cost is $120,000 and will also be paid over 20 years, which is also 240 months.
#
# For the house, the monthly payment \( M_h \) can be calculated using the loan formula:
# \[ M_h = \frac{P \times r \times (1 + r)^n}{(1 + r)^n - 1} \]
# where \( P \) is the loan amount, \( r \) is the monthly interest rate, and \( n \) is the number of months.
# Assuming an interest rate \( r \) of 0.008333 (1% per month, which is equivalent to 12% per year over 20 years), the calculation would be:
# \[ M_h = \frac{480,000 \times 0.008
# -------------------- Question:
# Janet pays $40/hour for 3 hours per week of clarinet lessons and $28/hour for 5 hours a week of piano lessons. How much more does she spend on piano lessons than clarinet lessons in a year?
# Answer:
# 1040
# Response:
# <reasoning>
# To determine how much more Janet spends on piano lessons than clarinet lessons in a year, we first need to calculate the weekly cost of each type of lesson and then find the difference.
#
# For clarinet lessons: Janet pays $40/hour and she takes 3 hours per week. So her weekly cost for clarinet lessons is $40 * 3 = $120.
# For piano lessons: Janet pays $28/hour and she takes 5 hours per week. So her weekly cost for piano lessons is $28 * 5 = $140.
# To find out how much more she spends on piano lessons than on clarinet lessons each week, we subtract the weekly cost of clarinet lessons from the weekly cost of piano lessons: $140 - $120 = $20.
# Since the question asks for the yearly difference, and there are 52 weeks in a year, we multiply the weekly difference by 52: $20 * 52 = $1040.
#
# </reasoning>
# <answer>
# Janet spends $1040 more on piano lessons than on clarinet lessons in a year. </answer>
# Extracted:
# Janet spends $1040 more on piano lessons than on clarinet lessons in a year.
# -------------------- Question:
# Sabrina is collecting herbs to make a poultice for her grandmother. She needs twice as many basil leaves as sage leaves and 5 fewer sage leaves than verbena leaves. If she needs 12 basil leaves, how many leaves total does she need?
# Answer:
# 29
# Response:
# <reasoning>
# Given the information, we need to find out how many sage and verbena leaves Sabrina needs and then calculate the total number of leaves needed. Here's how we can approach it:
#
# 1. We know that Sabrina needs twice as many basil leaves as sage leaves and she needs 12 basil leaves. Let's denote the number of sage leaves as \( x \). Therefore, we have:
#    \[
#    12 = 2x
#    \]
#    Solving for \( x \):
#    \[
#    x = \frac{12}{2} = 6 \text{ sage leaves}
#    \]
#
# 2. According to the problem, Sabrina needs 5 fewer sage leaves than verbena leaves. Let's denote the number of verbena leaves as \( y \). Thus, we have:
#    \[
#    x = y - 5
#    \]
#    We already found \( x = 6 \), so:
#    \[
#    6 = y - 5
#    \]
#    Solving for \( y \):
#    \[
#    y = 6 + 5 = 11 \text{ verbena leaves}
#    \]
#
# 3. Now we need to find the total
# Extracted:
# <reasoning>
# Given the information, we need to find out how many sage and verbena leaves Sabrina needs and then calculate the total number of leaves needed. Here's how we can approach it:
#
# 1. We know that Sabrina needs twice as many basil leaves as sage leaves and she needs 12 basil leaves. Let's denote the number of sage leaves as \( x \). Therefore, we have:
#    \[
#    12 = 2x
#    \]
#    Solving for \( x \):
#    \[
#    x = \frac{12}{2} = 6 \text{ sage leaves}
#    \]
#
# 2. According to the problem, Sabrina needs 5 fewer sage leaves than verbena leaves. Let's denote the number of verbena leaves as \( y \). Thus, we have:
#    \[
#    x = y - 5
#    \]
#    We already found \( x = 6 \), so:
#    \[
#    6 = y - 5
#    \]
#    Solving for \( y \):
#    \[
#    y = 6 + 5 = 11 \text{ verbena leaves}
#    \]
#
# 3. Now we need to find the total
# -------------------- Question:
# Over the past five years, on July 4th, the high temperature for Washington, DC has been: 90 degrees in 2020, 90 degrees in 2019, 90 degrees in 2018, 79 degrees in 2017 and 71 degrees in 2016. What is the average temperature for July 4th in Washington, DC over the past 5 years?
# Answer:
# 84
# Response:
# <reasoning>
# To calculate the average temperature for July 4th in Washington, DC over the past five years, we need to add up all the temperatures and divide them by the number of years (5).
#
# The temperatures given are:
# - 90 degrees in 2020
# - 90 degrees in 2019
# - 90 degrees in 2018
# - 79 degrees in 2017
# - 71 degrees in 2016
#
# We will add these temperatures together:
# \[ 90 + 90 + 90 + 79 + 71 = 410 \]
#
# Next, we divide the total by the number of years (5) to find the average:
# \[ \frac{410}{5} = 82 \]
#
# Thus, the average temperature for July 4th in Washington, DC over the past 5 years is 82 degrees.
# </reasoning>
# <answer>
# The average temperature for July 4th in Washington, DC over the past 5 years is 82 degrees.
# </answer>
# Extracted:
# The average temperature for July 4th in Washington, DC over the past 5 years is 82 degrees.
# -------------------- Question:
# Rene can finish reading 30 pages in 60 minutes. Lulu can read 27 pages in 60 minutes and Cherry can read 25 pages in 60 minutes. If they have been reading for 240 minutes now, how many pages have they finished reading in total?
# Answer:
# 328
# Response:
# <reasoning>
# To find the total number of pages Rene, Lulu, and Cherry have read in 240 minutes, we first need to determine the number of pages each of them can read per minute, and then calculate the total pages read by each person in 240 minutes. Finally, we sum up the pages read by all three.
#
# - **Rene's Reading Speed**: 30 pages in 60 minutes, which means 30/60 = 0.5 pages per minute.
# - **Lulu's Reading Speed**: 27 pages in 60 minutes, which means 27/60 = 0.45 pages per minute.
# - **Cherry's Reading Speed**: 25 pages in 60 minutes, which means 25/60 = 0.4167 pages per minute.
#
# Next, we calculate the total pages read by each of them in 240 minutes:
# - **Rene's Total Pages**: 240 * 0.5 = 120 pages.
# - **Lulu's Total Pages**: 240 * 0.45 = 108 pages.
# - **Cherry's Total
# Extracted:
# <reasoning>
# To find the total number of pages Rene, Lulu, and Cherry have read in 240 minutes, we first need to determine the number of pages each of them can read per minute, and then calculate the total pages read by each person in 240 minutes. Finally, we sum up the pages read by all three.
#
# - **Rene's Reading Speed**: 30 pages in 60 minutes, which means 30/60 = 0.5 pages per minute.
# - **Lulu's Reading Speed**: 27 pages in 60 minutes, which means 27/60 = 0.45 pages per minute.
# - **Cherry's Reading Speed**: 25 pages in 60 minutes, which means 25/60 = 0.4167 pages per minute.
#
# Next, we calculate the total pages read by each of them in 240 minutes:
# - **Rene's Total Pages**: 240 * 0.5 = 120 pages.
# - **Lulu's Total Pages**: 240 * 0.45 = 108 pages.
# - **Cherry's Total
# -------------------- Question:
# Martin rings the small bell 4 times more than 1/3 as often as the big bell. If he rings both of them a combined total of 52 times, how many times does he ring the big bell?
# Answer:
# 36
# Response:
# <reasoning>
# Let's denote the number of times the small bell is rung by \( s \) and the number of times the big bell is rung by \( b \). According mechanically to the problem, we have that the small bell is rung 4 times more than 1/3 as often as the big bell, which can be written as:
# \[ s = \frac{1}{3}b + 4 \]
#
# Also, since the total number of times they are rung is 52, we have:
# \[ s + b = 52 \]
#
# We need to solve this system of equations to find the values of \( s \) and \( b \).
#
# Substitute the expression for \( s \) from the first equation into the second equation:
# \[ \left(\frac{1}{3}b + 4\right) + b = 52 \]
# \[ \frac{1}{3}b + b + 4 = 52 \]
# \[ \frac{4}{3}b + 4 = 52 \]
#
# Subtract 4 from both sides to isolate the term with \( b \):
# \[ \frac{4}{3}b = 48 \]
# Multiply
# Extracted:
# <reasoning>
# Let's denote the number of times the small bell is rung by \( s \) and the number of times the big bell is rung by \( b \). According mechanically to the problem, we have that the small bell is rung 4 times more than 1/3 as often as the big bell, which can be written as:
# \[ s = \frac{1}{3}b + 4 \]
#
# Also, since the total number of times they are rung is 52, we have:
# \[ s + b = 52 \]
#
# We need to solve this system of equations to find the values of \( s \) and \( b \).
#
# Substitute the expression for \( s \) from the first equation into the second equation:
# \[ \left(\frac{1}{3}b + 4\right) + b = 52 \]
# \[ \frac{1}{3}b + b + 4 = 52 \]
# \[ \frac{4}{3}b + 4 = 52 \]
#
# Subtract 4 from both sides to isolate the term with \( b \):
# \[ \frac{4}{3}b = 48 \]
# Multiply
# -------------------- Question:
# Bert fills out the daily crossword puzzle in the newspaper every day. He uses up a pencil to fill out the puzzles every two weeks. On average, it takes him 1050 words to use up a pencil. How many words are in each crossword puzzle on average?
# Answer:
# 75
# Response:
# <reasoning>
# To find out how many words are in each crossword puzzle on average, we need to first determine how many crossword puzzles Bert completes in two weeks. As Bert uses up a pencil every two weeks and completes one crossword puzzle each day, and assuming there are 14 days in two weeks, Bert would complete 14 puzzles over two weeks.
#
# Since it takes 1050 words to use up a pencil, and Bert completes 14 puzzles on average over two weeks, we can calculate the average number of words per puzzle by dividing the total number of words per pencil by the number of puzzles. This gives us:
# \[ \text{Average words per puzzle} = \frac{1050 \text{ words}}{14 \text{ puzzles}} \]
# </reasoning>
# <answer>
# \[ \text{Average words per puzzle} = \frac{1050}{14} = 75 \]
# </answer>
# Extracted:
# \[ \text{Average words per puzzle} = \frac{1050}{14} = 75 \]
# -------------------- Question:
# Matt can make a batch of a dozen cookies using 2 pounds of flour.  He uses 4 bags of flour each weighing 5 pounds.  If Jim eats 15 cookies how many cookies are left?
# Answer:
# 105
# Response:
# <reasoning>
# First, let's determine the total amount of flour Matt has:
# - Matt has 4 bags of flour.
# - Each bag weighs 5 pounds.
#
# Total pounds of flour = 4 * 5 = 20 pounds.
#
# Since 2 pounds of flour are required to make a batch of a dozen (12) cookies, we can calculate the total number of batches of cookies Matt can make with 20 pounds of flour:
# - Total batches = 20 pounds / 2 pounds per batch = 10 batches.
#
# Therefore, Matt can make 10 batches of cookies, which means he can make:
# - 10 batches * 12 cookies per batch = 120 cookies in total.
#
# Now, if Jim eats 15 cookies, we need to calculate the number of cookies left:
# - Total cookies - Cookies eaten = 120 - 15 = 105 cookies.
#
# </reasoning>
# <answer>
# Matt will have 105 cookies left after Jim eats 15 cookies. </answer>
# Extracted:
# Matt will have 105 cookies left after Jim eats 15 cookies.
# -------------------- Question:
# James decides to build a tin house by collecting 500 tins in a week. On the first day, he collects 50 tins. On the second day, he manages to collect 3 times that number. On the third day, he collects 50 tins fewer than the number he collected on the second day. If he collects an equal number of tins on the remaining days of the week, what's the number of tins he collected each day for the rest of the week?
# Answer:
# 50
# Response:
# <reasoning>
# James collects 50 tins on the first day. On the second day, he collects 3 times that amount, which is \(3 \times 50 = 150\) tins. On the third day, he collects 50 tins fewer than the amount he collected on the second day, which is \(150 - 50 = 100\) tins. So far, on the first three days, he has collected \(50 + 150 + 100 = 300\) tins.
#
# He wants to collect a total of 500 tins in the week. Thus, for the remaining 4 days, he needs to collect \(500 - 300 = 200\) tins. Since he collects an equal number of tins each of these 4 days, he needs to divide the remaining 200 tins by the 4 days to find out how many tins he collects per day: \(200 \div 4 = 50\) tins.
#
# </reasoning>
#
# <answer>
# James collects 50 tins each of the remaining 4 days of the week
# Extracted:
# James collects 50 tins each of the remaining 4 days of the week
# -------------------- Question:
# A jar of jellybeans has 14 blue jellybeans, 26 purple jellybeans and 40 orange jellybeans. If there are 200 jellybeans in the jar, how many are there of the red color?
# Answer:
# 120
# Response:
# <reasoning>
# To find out how many red jellybeans are in the jar, we need to use the information provided about the count of jellybeans of other colors and the total number of jellybeans.
#
# First, we know the total number of jellybeans in the jar is .elementAt(200). Jellybeans that are not red are blue, purple, and orange and there are 14 (blue) + 26 (purple) + 40 (orange) = 80 jellybeans of these colors. Therefore, to find out how many red jellybeans there are, we subtract the number of blue, purple, and orange jellybeans from the total number of jellybeans in the jar.
#
# So, the number of red jellybeans = Total jellybeans - (Blue jellybeans + Purple jellybeans + Orange jellybeans).
# </reasoning>
# <answer>
# We subtract the total count of blue, purple, and orange jellybeans from the total number of jellybeans in the jar:
#
# 200 - (14 + 26 + 40) = 200 - 80 = 120
#
# Therefore, there are 120 red jellybeans in the jar.
# </answer>
# Extracted:
# We subtract the total count of blue, purple, and orange jellybeans from the total number of jellybeans in the jar:
#
# 200 - (14 + 26 + 40) = 200 - 80 = 120
#
# Therefore, there are 120 red jellybeans in the jar.
# -------------------- Question:
# Five adults and two children go to see a movie and buy $12 worth of concessions. The total cost of their trip is $76. If each child's ticket is $7, how much, in dollars, are the adult tickets?
# Answer:
# 10
# Response:
# <reasoning>
# We need to find the cost of one adult ticket. We know the total cost is $76, and we know that the total cost includes the cost of the concessions ($12) and the cost of the tickets for the 5 adults and 2 children. We also know each child's ticket costs $7. We can calculate the total cost of children's tickets as 2 * $7 = $14. Then, by subtracting the cost of the concessions and the cost of the children's tickets from the total cost, we can find out the total cost of adult tickets, which will help us find the cost of one adult ticket.
#
# Total cost of adult tickets = Total cost - (Cost of concessions + Cost of children's tickets)
# Let's solve this:
# </reasoning>
# <answer>
# Total cost of adult tickets = $76 - $12 - $14 = $50
# Total cost of adult tickets / Number of adults = Cost of one adult ticket
# $50 / 5 = $10
# The cost of each adult ticket is $10.
# </answer>
# Extracted:
# Total cost of adult tickets = $76 - $12 - $14 = $50
# Total cost of adult tickets / Number of adults = Cost of one adult ticket
# $50 / 5 = $10
# The cost of each adult ticket is $10.
# -------------------- Question:
# Janelle had 26 green marbles. Then she bought 6 bags of blue marbles. There were 10 marbles in each bag.  She created a gift of 6 green marbles and 8 blue marbles and gave it to a friend. How many marbles does Janelle have now?
# Answer:
# 72
# Response:
# <reasoning>
# Janelle originally had 26 green marbles. She bought 6 bags of blue marbles, with 10 marbles in each bag, so she bought a total of \(6 \times 10 = 60\) blue marbles.
#
# After giving away a gift, she gave away 6 green marbles and 8 blue marbles. To calculate the number of marbles she has now, we need to follow these steps:
# 1. Calculate the remaining green marbles: \(26 - 6 = 20\).
# 2. Calculate the remaining blue marbles: \(60 - 8 = 52\).
# 3. The total number of marbles she has now is the sum of the remaining green and blue marbles: \(20 + 52 = 72\).
#
# </reasoning>
# <answer>
# Janelle has 72 marbles now. </answer>
# Extracted:
# Janelle has 72 marbles now.
# -------------------- Question:
# Every day in a week, Siena bookmarks 30 website pages from the research she does on her browser. If Siena has 400 bookmarked pages on her bookmarks library now, how many pages will she have in her bookmarks library at the end of March?
# Answer:
# 1330
# Response:
# <reasoning>
# To solve this problem, let's begin by determining the total number of days in March. March 2023 (and any other non-leap year) has 31 days. Siena bookmarks 30 pages every week, and there are 4 weeks in a month (since 31 days / 7 days per week = 4 weeks and 3 days remainder). Since Siena will be working on the bookmarks for 4 weeks and on 3 extra days, we will calculate the number of new pages she will add in March based on the given rate of 30 pages per week.
#
# First, we calculate the total number of pages added from 4 weeks:
# \[ 4 \text{ weeks} \times 30 \text{ pages/week} = 120 \text{ pages} \]
#
# Next, we calculate the pages added in the remaining 3 days. Since we can only add full weeks' worth of bookmarks in those 3 days, we recognize that 3 days is less than a week. We find out how many pages would have been added in 3 days by dividing 3 days by 7 days per week and multiplying it by 30 pages per week:
#
# Extracted:
# <reasoning>
# To solve this problem, let's begin by determining the total number of days in March. March 2023 (and any other non-leap year) has 31 days. Siena bookmarks 30 pages every week, and there are 4 weeks in a month (since 31 days / 7 days per week = 4 weeks and 3 days remainder). Since Siena will be working on the bookmarks for 4 weeks and on 3 extra days, we will calculate the number of new pages she will add in March based on the given rate of 30 pages per week.
#
# First, we calculate the total number of pages added from 4 weeks:
# \[ 4 \text{ weeks} \times 30 \text{ pages/week} = 120 \text{ pages} \]
#
# Next, we calculate the pages added in the remaining 3 days. Since we can only add full weeks' worth of bookmarks in those 3 days, we recognize that 3 days is less than a week. We find out how many pages would have been added in 3 days by dividing 3 days by 7 days per week and multiplying it by 30 pages per week:
# -------------------- Question:
# An old pirate wants to leave his treasure on an island. He has 3500 gold coins. He wants to spread this equally across 5 chests. Additionally, he will put a total of 500 silver coins and twice as many bronze coins as silver, all distributed equally across the chests. How many coins in total will be in each chest?
# Answer:
# 1000
# Response:
# <reasoning>
# To determine the number of coins in each chest, we need to divide the total number of each type of coin by the number of chests.
#
# 1. **Gold Coins**: The pirate has 3500 gold coins, and they are to be divided equally among 5 chests.
#    \[
#    \text{Gold coins per chest} = \frac{3500}{5} = 700
#    \]
#
# 2. **Silver Coins**: The pirate has 500 silver coins, and these are also to be divided equally among 5 chests.
#    \[
#    \text{Silver coins per chest} = \frac{500}{5} = 100
#    \]
#
# 3. **Bronze Coins**: The pirate has twice as many bronze coins as silver coins. The number of bronze coins is:
#    \[
#    2 \times 500 = 1000
#    \]
#    These are to be distributed equally among 5 chests.
#    \[
#    \text{Bronze coins per chest} = \frac{1000}{5} = 200
#    \]
#
# 4. **Total Coins per Chest**:
# Extracted:
# <reasoning>
# To determine the number of coins in each chest, we need to divide the total number of each type of coin by the number of chests.
#
# 1. **Gold Coins**: The pirate has 3500 gold coins, and they are to be divided equally among 5 chests.
#    \[
#    \text{Gold coins per chest} = \frac{3500}{5} = 700
#    \]
#
# 2. **Silver Coins**: The pirate has 500 silver coins, and these are also to be divided equally among 5 chests.
#    \[
#    \text{Silver coins per chest} = \frac{500}{5} = 100
#    \]
#
# 3. **Bronze Coins**: The pirate has twice as many bronze coins as silver coins. The number of bronze coins is:
#    \[
#    2 \times 500 = 1000
#    \]
#    These are to be distributed equally among 5 chests.
#    \[
#    \text{Bronze coins per chest} = \frac{1000}{5} = 200
#    \]
#
# 4. **Total Coins per Chest**:
# -------------------- Question:
# Ephraim has two machines that make necklaces for his store. On Sunday the first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine. How many necklaces were made in total on Sunday?
# Answer:
# 153
# Response:
# <reasoning>
# To solve this problem, we need to find out how many necklaces the second machine made and then add that number to the number made by the first machine.
#
# The first machine made 45 necklaces. The second machine made 2.4 times as many necklaces as the first machine. Therefore, the number of necklaces made by the second machine is \(2.4 \times 45\).
#
# Let's calculate the number of necklaces made by the second machine:
# \[ 2.4 \times 45 = 108 \]
#
# Now, we add the number of necklaces made by both machines to find the total:
# \[ \text{Total necklaces} = 45 + 108 = 153 \]
#
# So, the total number of necklaces made on Sunday is 153.
#
# </reasoning>
#
# <answer>
# 153
# </answer>
# Extracted:
# 153
# -------------------- Question:
# Zach baked cookies for a bake sale. On Monday he baked 32 cookies. On Tuesday he ran out of sugar and could only bake half of the number of cookies he baked the day before. On Wednesday he baked three times the number of cookies he did on Tuesday, but his brother ate 4 of those cookies. How many cookies did he have at the end of the three days?
# Answer:
# 92
# Response:
# <reasoning>
# Zach's cookie baking pattern follows the following steps:
# 1. On Monday: Zach baked 32 cookies.
# 2. On Tuesday: He baked half of the quantity he baked on Monday. So, he baked \( \frac{32}{2} = 16 \) cookies.
# 3. On Wednesday: He baked three times the number of cookies he baked on Tuesday, which would be \( 16 \times 3 = 48 \) cookies. But his brother ate 4 of these cookies, so he had \( 48 - 4 = 44 \) cookies left.
#
# Now, we need to sum up the cookies he baked on Monday, Tuesday, and Wednesday at the end:
# - Cookies on Monday: 32
# - Cookies on Tuesday: 16
# - Cookies on Wednesday (with his brother): 44
#
# Therefore, the total number of cookies he made at the end of the three days is \( 32 + 16 + 44 \).
# </reasoning>
# <answer>
# Summing up all the cookies he baked:
# \[ 32 + 16 + 44 = 92 \]
#
# Therefore, Zach had 92 cookies
# Extracted:
# Summing up all the cookies he baked:
# \[ 32 + 16 + 44 = 92 \]
#
# Therefore, Zach had 92 cookies
# -------------------- Question:
# Mark and James need a total of 14 dice that are 12 sided to play their game.  Mark has a bag of 10 dice and 60% of them are 12 sided.  James has a bag of 8 dice and 75% of them are 12 sided.  How many dice will the boys need to buy to play their game?
# Answer:
# 2
# Response:
# <reasoning>
# To determine how many dice Mark and James need to buy, we'll first calculate the number of 12-sided dice each already has and then find out how many more dice they need in total, considering they require 14 dice in total.
#
# For Mark:
# - Total dice in Mark's bag: 10 dice
# - Percentage of 12-sided dice in Mark's bag: 60%
# - Number of 12-sided dice in Mark's bag: 0.60 * 10 = 6 dice
#
# For James:
# - Total dice in James's bag: 8 dice
# - Percentage of 12-sided dice in James's bag: 75%
# - Number of 12-sided dice in James's bag: 0.75 * 8 = 6 dice
#
# Given that they need 14 dice in total:
# - Combined number of 12-sided dice they currently have: 6 (Mark) + 6 (James) = 12 dice
# - Remaining dice needed to play the game: 14 - 12 = 2 dice
#
# </reasoning>
# <answer>
# Mark and James need to buy 2 more dice to play their game.
#
# Extracted:
# Mark and James need to buy 2 more dice to play their game.
# -------------------- Question:
# Erin counts six trolls hiding by the path in the forest, 6 less than four times that number of trolls hiding under the bridge, and half as many trolls hiding in the plains as under the bridge. How many trolls did she count in total?
# Answer:
# 33
# Response:
# <reasoning>
# Erin counts 6 trolls hiding by the path. This represents four times the number of trolls under the bridge minus 6. Let's denote the number of trolls under the bridge as \( x \). According to the problem, \( 6 = 4x - 6 \).
#
# First, we solve the equation to find the value of \( x \):
#
# \[
# 6 = 4x - 6
# \]
#
# Add 6 to both sides to isolate the term with the variable:
#
# \[
# 12 = 4x
# \]
#
# Next, divide both sides by 4 to solve for \( x \):
#
# \[
# x = 3
# \]
#
# So, there are 3 trolls under the bridge. The problem states that there are half as many trolls hiding in the plains as under the bridge. Thus, the number of trolls in the plains is:
#
# \[
# \frac{x}{2} = \frac{3}{2} = 1.5
# \]
#
# Now, summing the counts from each location:
#
# - Path: 6 trolls
# - Bridge: 3 trolls
# - Plains: 1.5 trolls
#
# The total number of trolls that Erin counted is:
#
# \[
# 6 + 3 + 1
# Extracted:
# <reasoning>
# Erin counts 6 trolls hiding by the path. This represents four times the number of trolls under the bridge minus 6. Let's denote the number of trolls under the bridge as \( x \). According to the problem, \( 6 = 4x - 6 \).
#
# First, we solve the equation to find the value of \( x \):
#
# \[
# 6 = 4x - 6
# \]
#
# Add 6 to both sides to isolate the term with the variable:
#
# \[
# 12 = 4x
# \]
#
# Next, divide both sides by 4 to solve for \( x \):
#
# \[
# x = 3
# \]
#
# So, there are 3 trolls under the bridge. The problem states that there are half as many trolls hiding in the plains as under the bridge. Thus, the number of trolls in the plains is:
#
# \[
# \frac{x}{2} = \frac{3}{2} = 1.5
# \]
#
# Now, summing the counts from each location:
#
# - Path: 6 trolls
# - Bridge: 3 trolls
# - Plains: 1.5 trolls
#
# The total number of trolls that Erin counted is:
#
# \[
# 6 + 3 + 1
# -------------------- Question:
# Karen packs peanut butter sandwiches in her daughter's lunch 2 randomly chosen days of the week. The other 3 school days, she packs a ham sandwich. She packs a piece of cake on one randomly chosen day and cookies the other four days. What is the probability, expressed as a percentage, that Karen packs a ham sandwich and cake on the same day?
# Answer:
# 12
# Response:
# <reasoning>
# To find the probability that Karen packs a ham sandwich and cake on the same day, we need to understand the likelihood of these events happening on the same day based on the rules provided.
#
# First, we calculate the probability that Karen packs a ham sandwich on a given day. Since she packs peanut butter sandwiches 2 days out of 5, she packs ham sandwiches on 3 out of 5 days (since the total days are 5). So, the probability of packing a ham sandwich on a given day is:
# \[ \text{Probability (ham sandwich)} = \frac{3}{5} \]
#
# Next, we consider the probability that she packs cake on a given day. Since she packs cake 1 day out of 5, the probability of packing cake on a given day is:
# \[ \text{Probability (cake)} = \frac{1}{5} \]
#
# To find the combined probability that she packs both a ham sandwich and cake on the same day, we multiply the individual probabilities of these events happening on the same day:
# \[ \text{Probability (ham sandwich and cake)} = \frac{3}{5} \times \frac{1}{5} = \frac{3}{25} \]
#
# To
# Extracted:
# <reasoning>
# To find the probability that Karen packs a ham sandwich and cake on the same day, we need to understand the likelihood of these events happening on the same day based on the rules provided.
#
# First, we calculate the probability that Karen packs a ham sandwich on a given day. Since she packs peanut butter sandwiches 2 days out of 5, she packs ham sandwiches on 3 out of 5 days (since the total days are 5). So, the probability of packing a ham sandwich on a given day is:
# \[ \text{Probability (ham sandwich)} = \frac{3}{5} \]
#
# Next, we consider the probability that she packs cake on a given day. Since she packs cake 1 day out of 5, the probability of packing cake on a given day is:
# \[ \text{Probability (cake)} = \frac{1}{5} \]
#
# To find the combined probability that she packs both a ham sandwich and cake on the same day, we multiply the individual probabilities of these events happening on the same day:
# \[ \text{Probability (ham sandwich and cake)} = \frac{3}{5} \times \frac{1}{5} = \frac{3}{25} \]
#
# To
# -------------------- Question:
# A four-layer pyramid is being built with each layer having three times as many sandstone blocks as the layer above it. The top layer is a single block. How many sandstone blocks are in the pyramid?
# Answer:
# 40
# Response:
# <reasoning>
# To find the total number of sandstone blocks in the four-layer pyramid, we will work our way down from the top layer to the bottom layer and calculate the number of blocks in each layer and their cumulative total.
#
# Starting from the top, the top layer has 1 block. Given that each layer has three times as many blocks as the layer above it, we can find the number of blocks in subsequent layers as follows:
# - 1st layer (top): 1 block
# - 2nd layer: 1 * 3 = 3 blocks
# - 3rd layer: 3 * 3 = 9 blocks
# - 4th layer (bottom): 9 * 3 = 27 blocks
#
# To find the total number of blocks in the pyramid, we sum the blocks from all the layers:
# \[ 1 + 3 + 9 + 27 \]
#
# We can calculate the sum step by step:
# \[ 1 + 3 = 4 \]
# \[ 4 + 9 = 13 \]
# \[ 13 + 27 = 40 \]
#
# Thus, the total number of sandstone blocks in the pyramid is 40.
# </reasoning>
#
# <answer
# Extracted:
# <reasoning>
# To find the total number of sandstone blocks in the four-layer pyramid, we will work our way down from the top layer to the bottom layer and calculate the number of blocks in each layer and their cumulative total.
#
# Starting from the top, the top layer has 1 block. Given that each layer has three times as many blocks as the layer above it, we can find the number of blocks in subsequent layers as follows:
# - 1st layer (top): 1 block
# - 2nd layer: 1 * 3 = 3 blocks
# - 3rd layer: 3 * 3 = 9 blocks
# - 4th layer (bottom): 9 * 3 = 27 blocks
#
# To find the total number of blocks in the pyramid, we sum the blocks from all the layers:
# \[ 1 + 3 + 9 + 27 \]
#
# We can calculate the sum step by step:
# \[ 1 + 3 = 4 \]
# \[ 4 + 9 = 13 \]
# \[ 13 + 27 = 40 \]
#
# Thus, the total number of sandstone blocks in the pyramid is 40.
# </reasoning>
#
# <answer
# -------------------- Question:
# The cost of Joe's new HVAC system is $20,000.  It includes 2 conditioning zones, each with 5 vents.  In dollars, what is the cost of the system per vent?
# Answer:
# 2,000
# Response:
# <reasoning>
# To solve this problem, we first need to calculate the total number of vents. Since the HVAC system provides 2 conditioning zones and each zone includes 5 vents, the total number of vents is:
# \[ 2 \, \text{zones} \times 5 \, \text{vents per zone} = 10 \, \text{vents} \]
#
# Next, we know the total cost of the HVAC system is $20,000. To find the cost per vent, we would divide the total cost by the total number of vents:
# \[ \text{Cost per vent} = \frac{20000}{10} \]
#
# Carrying out the division:
# \[ \text{Cost per vent} = 2000 \, \text{dollars per vent} \]
#
# </reasoning>
# <answer>
# The cost of Joe's new HVAC system per vent is 2000 dollars. </answer>
# Extracted:
# The cost of Joe's new HVAC system per vent is 2000 dollars.
# -------------------- Question:
# Trent walked 4 blocks from his house to the bus stop. He rode the bus 7 blocks to the library. Later, he came home the same way. How many blocks did Trent travel in all?
# Answer:
# 22
# Response:
# <reasoning>
# Trent walked 4 blocks from his house to the bus stop, then he rode the bus for 7 blocks to the library, making a total of 4 + 7 = 11 blocks for the round trip to the library. Since he traveled the same way back home, he would also travel an additional 11 blocks to return. Therefore, the total number of blocks he traveled is 11 (to the library) + 11 (back home) = 22 blocks.
# </reasoning>
# <answer>
# 22 </answer>
#
# Extracted:
# 22
# -------------------- Question:
# Lee had $10 and his friend had $8. They went to a restaurant where they ordered chicken wings for $6 and a chicken salad for $4. They also got 2 sodas for $1.00 each. The tax came to $3. How much change should they have received in total?
# Answer:
# 3
# Response:
# <reasoning>
# To find out how much change Lee and his friend should have received in total, let's start by calculating the total cost of their meal:
#
# 1. **Cost of Chicken Wings**: $6
# 2. **Cost of Chicken Salad**: $4
# 3. **Cost of Sodas**: 2 * $1.00 = $2.00
# 4. **Tax**: $3.00
#
# Adding these up:
# \[ \text{Total Cost} = 6 + 4 + 2 + 3 = 15 \text{ dollars} \]
#
# Next, we calculate the total amount of money they had:
#
# - Lee had $10 and his friend had $8, so together they had:
# \[ 10 + 8 = 18 \text{ dollars} \]
#
# To find out the total change, we subtract the total cost from the total money they had:
# \[ \text{Total Change} = 18 - 15 = 3 \text{ dollars} \]
#
# This total change $3 is the amount they should have received. Since it's an amount and not an individual amount, we need to specify that there is a total of $3.
#
# But the question
# Extracted:
# <reasoning>
# To find out how much change Lee and his friend should have received in total, let's start by calculating the total cost of their meal:
#
# 1. **Cost of Chicken Wings**: $6
# 2. **Cost of Chicken Salad**: $4
# 3. **Cost of Sodas**: 2 * $1.00 = $2.00
# 4. **Tax**: $3.00
#
# Adding these up:
# \[ \text{Total Cost} = 6 + 4 + 2 + 3 = 15 \text{ dollars} \]
#
# Next, we calculate the total amount of money they had:
#
# - Lee had $10 and his friend had $8, so together they had:
# \[ 10 + 8 = 18 \text{ dollars} \]
#
# To find out the total change, we subtract the total cost from the total money they had:
# \[ \text{Total Change} = 18 - 15 = 3 \text{ dollars} \]
#
# This total change $3 is the amount they should have received. Since it's an amount and not an individual amount, we need to specify that there is a total of $3.
#
# But the question
# -------------------- Question:
# Andy walks 50 meters from his house to school. After school, he comes back to the house and goes to the market. If he walks 140 meters in total, how many meters is the distance between the house and the market?
# Answer:
# 40
# Response:
# <reasoning>
# Based on the information given, we can determine the distance between the house and the market as follows:
#
# 1. Andy walks 50 meters from his house to school.
# 2. After school, he walks back to his house, which means he walks another 50 meters from school to his house.
# 3. We know that Andy walks a total of 140 meters.
#
# This means that the walking back and forth between his house and school (50 + 50 = 100 meters) accounts for 100 meters of the total 140 meters walked.
#
# Thus, the remaining distance can be calculated by subtracting the 100 meters already accounted for from the total distance:
# ...
# <answer>
# The distance between the house and the market is 40 meters. </answer>
#
# Extracted:
# The distance between the house and the market is 40 meters.
# -------------------- Question:
# Tara has been planning to buy a laptop which costs $1000. A computer shop accepts payment in installments of $65 per month provided that a 20% down payment is made. If Tara wants to pay an additional $20 for the down payment, how much will her balance be after paying for 4 months?
# Answer:
# 520
# Response:
# <reasoning>
# First, let's determine the down payment Tara needs to make. A 20% down payment on a $1000 laptop is $1000 \times 0.20 = $200. Since Tara decides to pay an additional $20 for the down payment, her total down payment will be $200 + $20 = $220.
#
# After the down payment, the balance for the remaining amount will be $1000 - $220 = $780.
#
# Then, we need to calculate the payment for 4 months, knowing she pays $65 per month. The total payment for 4 months will be $65 \times 4 = $260.
#
# Therefore, the balance after 4 months will be the remaining balance after the down payment minus the payment made over the 4 months: $780 - $260 = $520.
#
# Thus, the balance after 4 months of payments will be $520.
# </reasoning>
# <answer>
# $520
# </answer>
# Extracted:
# $520
# -------------------- Question:
# Bill picked 50 apples from the orchard with his wife and two children.  He sends each of his kids to school with 3 apples for their two favorite teachers.  His wife Jill bakes two apple pies, using 10 apples per pie. How many apples does Bill have left?
# Answer:
# 24
# Response:
# <reasoning>
# - Bill picked 50 apples.
# - Bill sends 3 apples to each of his 2 children, which totals 3 * 2 = 6 apples.
# - His wife bakes 2 apple pies, using 10 apples per pie, which totals 2 * 10 = 20 apples.
# - Therefore, the total number of apples sent away or used is 6 (to his children) + 20 (for the pies) = 26 apples.
# - The number of apples left is the number of apples Bill initially picked minus the apples that were sent away or used, which is 50 - 26 = 24 apples.
# </reasoning>
# <answer>
# Bill has 24 apples left.
# </answer>
# Extracted:
# Bill has 24 apples left.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s, est. speed input: 63.38 toks/s, output: 25.69 toks/s]
# 'There are 2 r\'s in the word "strawberry."'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it, est. speed input: 14.05 toks/s, output: 29.09 toks/s]
# '<reasoning>\nTo find out how many times the letter \'r\' appears in the word "strawberry", we can go through the word character by character and count each occurrence of \'r\'. In "strawberry", the letter \'r\' appears 3 times: once in the beginning, once in the middle, and once at the end of the word.\n</reasoning>\n<answer>\n3\n</answer>'

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Llama 3.2 Conversational notebook. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(1B_and_3B)-Conversational.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
